# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_selector as selector
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, precision_score, recall_score, f1_score

# %%
# Load datasets
df = pd.read_csv('/kaggle/input/credit-card-transactions/credit_card_transactions-ibm_v2.csv')
user = pd.read_csv('/kaggle/input/credit-card-transactions/sd254_users.csv')
card = pd.read_csv('/kaggle/input/credit-card-transactions/sd254_cards.csv')

# %%
# Strip any leading/trailing spaces in column names
df.columns = df.columns.str.strip()
user.columns = user.columns.str.strip()
card.columns = card.columns.str.strip()

## Data preprocessing for user
user["User"] = range(2000)  # Create User ID to join with 'card'
## Remove the dollar signs
user["Yearly Income - Person"] = user["Yearly Income - Person"].str.replace("$", "").astype(float)
user["Total Debt"] = user["Total Debt"].str.replace("$", "").astype(float)
user["User_Location_Income"] = user["Per Capita Income - Zipcode"].str.replace("$", "").astype(float)

## Define new variable indicating users' retirement status
user['Retired'] = 'No'
user.loc[user['Current Age'] > user['Retirement Age'], 'Retired'] = 'Yes'

# %%
## Define variables that are the ratio of their income, debt, and the income level at their location
user['Person_Location_Income_ratio'] = user["Yearly Income - Person"] / (user["User_Location_Income"] + 0.01)
user['Person_Income_toDebt'] = user["Yearly Income - Person"] / (user["Total Debt"] + 0.01)
user['Location_Income_toDebt'] = user["User_Location_Income"] / (user["Total Debt"] + 0.01)

## Select variables used for further analysis
user = user[['User', 'Gender', "Current Age", "Retired", "User_Location_Income", 'Yearly Income - Person', "Total Debt", "Num Credit Cards", 'Person_Location_Income_ratio','Person_Income_toDebt','Location_Income_toDebt']]

## Data preprocessing for cards
card["User_Card"] = card['User'].astype(str) + '_' + card['CARD INDEX'].astype(str)  ## Create card id to join with transaction data
## Remove the dollar sign
card["Credit Limit"] = card["Credit Limit"].str.replace("$", "").astype(float)

## Select variables of interest
card = card[["User_Card", "User", 'Card Brand', "Card Type", "Credit Limit"]]
## Left join with 'user'
card = card.merge(user, on='User', how='left')
card = card.drop(columns=['User'])

## Take a look
card.head()
# Out:
#   User_Card  Card Brand        Card Type  Credit Limit  Gender  Current Age  \
# 0       0_0        Visa            Debit       24295.0  Female           53
# 1       0_1        Visa            Debit       21968.0  Female           53
# 2       0_2        Visa            Debit       46414.0  Female           53
# 3       0_3        Visa           Credit       12400.0  Female           53
# 4       0_4  Mastercard  Debit (Prepaid)          28.0  Female           53
#
#   Retired  User_Location_Income  Yearly Income - Person  Total Debt  \
# 0      No               29278.0                 59696.0    127613.0
# 1      No               29278.0                 59696.0    127613.0
# 2      No               29278.0                 59696.0    127613.0
# 3      No               29278.0                 59696.0    127613.0
# 4      No               29278.0                 59696.0    127613.0
#
#    Num Credit Cards  Person_Location_Income_ratio  Person_Income_toDebt  \
# 0                 5                      2.038936              0.467789
# 1                 5                      2.038936              0.467789
# 2                 5                      2.038936              0.467789
# 3                 5                      2.038936              0.467789
# 4                 5                      2.038936              0.467789
#
#    Location_Income_toDebt
# 0                0.229428
# 1                0.229428
# 2                0.229428
# 3                0.229428
# 4                0.229428

# %%
## Create the 'User_Card' index to join with credit card information
df["User_Card"] = df['User'].astype(str) + '_' + df['Card'].astype(str)
## Remove the dollar sign
df["Amount"] = df["Amount"].str.replace("$", "").astype(float)
## Keep data with a positive amount
df = df[df['Amount'] > 0]
df = df.merge(card, on='User_Card', how='left')

## Remove columns that will not be used
df = df.drop(columns=['User', 'Card', 'User_Card', "Errors?", "Merchant Name", "Merchant State", "Zip", 'MCC'])

## Create a column with combined transaction time
df["Transaction_Time"] = df["Year"].astype(str) + '-' + df["Month"].astype(str) + '-' + df["Day"].astype(str) + ' ' + df["Time"]
df["Transaction_Time"] = pd.to_datetime(df["Transaction_Time"])

## Day of the week
df["Weekday"] = df["Transaction_Time"].dt.day_name()

## Split the time of day into 8 different periods based on the hour
df['Time_of_Day'] = ''
df.loc[(df['Transaction_Time'].dt.hour >= 23) | (df['Transaction_Time'].dt.hour < 2), 'Time_of_Day'] = 'Midnight'
df.loc[(df['Transaction_Time'].dt.hour >= 2) & (df['Transaction_Time'].dt.hour < 5), 'Time_of_Day'] = 'Early Morning'
df.loc[(df['Transaction_Time'].dt.hour >= 5) & (df['Transaction_Time'].dt.hour < 8), 'Time_of_Day'] = 'Morning'
df.loc[(df['Transaction_Time'].dt.hour >= 8) & (df['Transaction_Time'].dt.hour < 11), 'Time_of_Day'] = 'Late Morning'
df.loc[(df['Transaction_Time'].dt.hour >= 11) & (df['Transaction_Time'].dt.hour < 14), 'Time_of_Day'] = 'Noon'
df.loc[(df['Transaction_Time'].dt.hour >= 14) & (df['Transaction_Time'].dt.hour < 17), 'Time_of_Day'] = 'Afternoon'
df.loc[(df['Transaction_Time'].dt.hour >= 17) & (df['Transaction_Time'].dt.hour < 20), 'Time_of_Day'] = 'Evening'
df.loc[(df['Transaction_Time'].dt.hour >= 20) & (df['Transaction_Time'].dt.hour < 23), 'Time_of_Day'] = 'Late Night'

## The last digit of the transaction amount can be a trait of fraud
df['last_digit'] = df['Amount'].astype(str).str[-1]

## Remove columns that will not be used
df = df.drop(columns=["Time", "Transaction_Time"])

## Show what the dataframe looks like after all the steps
df.head(10)
# Out:
#    Year  Month  Day  Amount           Use Chip  Merchant City Is Fraud?  \
# 0  2002      9    1  134.09  Swipe Transaction       La Verne        No
# 1  2002      9    1   38.48  Swipe Transaction  Monterey Park        No
# 2  2002      9    2  120.34  Swipe Transaction  Monterey Park        No
# 3  2002      9    2  128.95  Swipe Transaction  Monterey Park        No
# 4  2002      9    3  104.71  Swipe Transaction       La Verne        No
# 5  2002      9    3   86.19  Swipe Transaction  Monterey Park        No
# 6  2002      9    4   93.84  Swipe Transaction  Monterey Park        No
# 7  2002      9    4  123.50  Swipe Transaction  Monterey Park        No
# 8  2002      9    5   61.72  Swipe Transaction  Monterey Park        No
# 9  2002      9    5   57.10  Swipe Transaction       La Verne        No
#
#   Card Brand Card Type  Credit Limit  ... User_Location_Income  \
# 0       Visa     Debit       24295.0  ...              29278.0
# 1       Visa     Debit       24295.0  ...              29278.0
# 2       Visa     Debit       24295.0  ...              29278.0
# 3       Visa     Debit       24295.0  ...              29278.0
# 4       Visa     Debit       24295.0  ...              29278.0
# 5       Visa     Debit       24295.0  ...              29278.0
# 6       Visa     Debit       24295.0  ...              29278.0
# 7       Visa     Debit       24295.0  ...              29278.0
# 8       Visa     Debit       24295.0  ...              29278.0
# 9       Visa     Debit       24295.0  ...              29278.0
#
#    Yearly Income - Person Total Debt  Num Credit Cards  \
# 0                 59696.0   127613.0                 5
# 1                 59696.0   127613.0                 5
# 2                 59696.0   127613.0                 5
# 3                 59696.0   127613.0                 5
# 4                 59696.0   127613.0                 5
# 5                 59696.0   127613.0                 5
# 6                 59696.0   127613.0                 5
# 7                 59696.0   127613.0                 5
# 8                 59696.0   127613.0                 5
# 9                 59696.0   127613.0                 5
#
#    Person_Location_Income_ratio  Person_Income_toDebt  Location_Income_toDebt  \
# 0                      2.038936              0.467789                0.229428
# 1                      2.038936              0.467789                0.229428
# 2                      2.038936              0.467789                0.229428
# 3                      2.038936              0.467789                0.229428
# 4                      2.038936              0.467789                0.229428
# 5                      2.038936              0.467789                0.229428
# 6                      2.038936              0.467789                0.229428
# 7                      2.038936              0.467789                0.229428
# 8                      2.038936              0.467789                0.229428
# 9                      2.038936              0.467789                0.229428
#
#      Weekday   Time_of_Day  last_digit
# 0     Sunday       Morning           9
# 1     Sunday       Morning           8
# 2     Monday       Morning           4
# 3     Monday       Evening           5
# 4    Tuesday       Morning           1
# 5    Tuesday          Noon           9
# 6  Wednesday       Morning           4
# 7  Wednesday       Morning           5
# 8   Thursday       Morning           2
# 9   Thursday  Late Morning           1
#
# [10 rows x 23 columns]

# %%
def data_preprocessing(X):
    ## Separate the column by numerical or categorical
    numerical_columns_selector = selector(dtype_exclude=object)
    categorical_columns_selector = selector(dtype_include=object)
    numerical_columns = numerical_columns_selector(X)
    categorical_columns = categorical_columns_selector(X)
    
    ## One Hot encoding the categorical variables and scale the numerical ones
    categorical_preprocessor = OneHotEncoder(handle_unknown="ignore")
    numerical_preprocessor = StandardScaler()
    
    preprocessor = ColumnTransformer(
        transformers=[
            ("one-hot-encoder", categorical_preprocessor, categorical_columns),
            ("standard_scaler", numerical_preprocessor, numerical_columns)
        ]
    )
    
    ## Transform the variable
    X_preprocessed = preprocessor.fit_transform(X)
    
    ## Save the feature names for variable importance
    feature_names = preprocessor.get_feature_names_out()
    
    return X_preprocessed, feature_names

# %%
def resample_split(rsd):
    # Calculate the desired number of fraud cases based on the desired proportion
    desired_proportion = 0.05
    total_samples = 500000
    fraud_samples = int(total_samples * desired_proportion)
    
    # Create RandomUnderSampler with the desired sampling strategy
    rus = RandomUnderSampler(sampling_strategy={0: total_samples - fraud_samples, 1: fraud_samples}, random_state=rsd)
    
    # Apply random undersampling to the original dataset
    X_resampled, y_resampled = rus.fit_resample(X, y)
    
    ## Perform data preprocessing on the resampled data, and keep the feature names
    X_preprocessed, feature_names = data_preprocessing(X_resampled)
    
    # Split the resampled data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y_resampled, test_size=0.2, stratify=y_resampled, random_state=rsd)
    
    return X_train, X_test, y_train, y_test, feature_names

# %%
## Select columns that will be used for model construction
col_formd = ["Merchant City", "Gender", "Current Age", 'Card Brand', "Card Type", "Credit Limit", "Amount", "Use Chip", "Year", "Month", "Retired", "Person_Location_Income_ratio", "Person_Income_toDebt", "Location_Income_toDebt", "Weekday", "Time_of_Day", "last_digit"]

# Split the dataset into features (X) and target variable (y)
X = df[col_formd]
y = df['Is Fraud?'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
def cus_metrics(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    auc = roc_auc_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    
    return accuracy, auc, precision, recall, f1

# %%
## Create an empty dictionary to store the results
results = {}

## Assign seed for each repetition
sd_list = [1234, 3456, 4567, 6789, 7890, 1111, 2222, 3333, 4444, 5555, 6666, 7777, 8888, 9999, 1010, 2020, 3030, 4040, 5050, 6060, 7070, 8080, 9090, 8765, 4321, 9054, 3388, 3360, 3596, 1998]

for rsd in sd_list:
    ## Perform undersampling to make the data more balanced
    X_train, X_test, y_train, y_test, feature_names = resample_split(rsd)
    
    ## Create LightGBM dataset
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)
    
    ## Define the parameters
    params = {
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'metric': {'binary_logloss', 'binary_error', 'auc'},
        'num_leaves': 31,
        'learning_rate': 0.1,
        'lambda_l1': 0.01,  ## Avoid overfitting
        'feature_fraction': 0.9,
        'bagging_fraction': 0.8,
        'bagging_freq': 5,
        'verbose': 0
    }
    
    ## Train the model

    model = lgb.train(params, lgb_train, num_boost_round=100, valid_sets=lgb_eval)

    
    ## Predict the model using the testing sets
    y_pred = model.predict(X_test, num_iteration=model.best_iteration)
    y_pred = (y_pred > 0.5).astype(int)  # Convert probabilities to binary predictions
    
    ## Obtain the model performance metrics
    accuracy, auc, precision, recall, f1 = cus_metrics(y_test, y_pred)
    
    ## Get the top 20 feature importance
    feature_importance = model.feature_importance(importance_type='gain')
    feature_importance_dict = dict(zip(feature_names, feature_importance))
    top20feat = sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True)[:20]
    
    ## Save the result
    results[f"Seed {rsd}"] = {
        'Accuracy': accuracy,
        'AUC': auc,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1,
        'Top 20 Important Features': top20feat
    }

# %%
## Flatten the dictionary to separate feature names and values
flattened_results = []
for seed, data in results.items():
    row = {
        'Seed': seed,
        'Accuracy': data['Accuracy'],
        'AUC': data['AUC'],
        'Precision': data['Precision'],
        'Recall': data['Recall'],
        'F1 Score': data['F1 Score']
    }
    for i, (feat_name, feat_value) in enumerate(data['Top 20 Important Features']):
        row[f'Top{i+1} Feature Name'] = feat_name
        row[f'Top{i+1} Feature Value'] = feat_value
    flattened_results.append(row)

## Create a DataFrame from the flattened dictionary
res_df = pd.DataFrame(flattened_results)

# Save the DataFrame as a CSV file
res_df.to_csv('results_with_top_features.csv', index=False)

# Display the results DataFrame
res_df
# Out:
#          Seed  Accuracy       AUC  Precision  Recall  F1 Score  \
# 0   Seed 1234   0.97800  0.823674   0.876142  0.6522  0.747764
# 1   Seed 3456   0.97811  0.825437   0.875100  0.6558  0.749743
# 2   Seed 4567   0.97716  0.822284   0.858690  0.6502  0.740041
# 3   Seed 6789   0.97705  0.821847   0.856954  0.6494  0.738878
# 4   Seed 7890   0.97802  0.827474   0.868684  0.6602  0.750227
# 5   Seed 1111   0.97710  0.820926   0.859989  0.6474  0.738704
# 6   Seed 2222   0.97745  0.828121   0.854011  0.6622  0.745973
# 7   Seed 3333   0.97727  0.821489   0.862923  0.6484  0.740436
# 8   Seed 4444   0.97768  0.825495   0.864594  0.6564  0.746248
# 9   Seed 5555   0.97781  0.829163   0.860327  0.6640  0.749520
# 10  Seed 6666   0.97754  0.824189   0.863901  0.6538  0.744308
# 11  Seed 7777   0.97804  0.828526   0.867016  0.6624  0.751020
# 12  Seed 8888   0.97821  0.828900   0.870307  0.6630  0.752639
# 13  Seed 9999   0.97753  0.829205   0.853765  0.6644  0.747273
# 14  Seed 1010   0.97777  0.826963   0.863767  0.6594  0.747873
# 15  Seed 2020   0.97730  0.820937   0.864778  0.6472  0.740334
# 16  Seed 3030   0.97818  0.829547   0.868270  0.6644  0.752776
# 17  Seed 4040   0.97746  0.824811   0.860746  0.6552  0.744038
# 18  Seed 5050   0.97867  0.833121   0.872628  0.6714  0.758901
# 19  Seed 6060   0.97795  0.824974   0.872170  0.6550  0.748144
# 20  Seed 7070   0.97724  0.816642   0.872335  0.6382  0.737122
# 21  Seed 8080   0.97766  0.826053   0.862992  0.6576  0.746425
# 22  Seed 9090   0.97801  0.826332   0.870797  0.6578  0.749459
# 23  Seed 8765   0.97744  0.820916   0.868223  0.6470  0.741462
# 24  Seed 4321   0.97802  0.826432   0.870831  0.6580  0.749601
# 25  Seed 9054   0.97719  0.823816   0.856356  0.6534  0.741237
# 26  Seed 3388   0.97680  0.817642   0.859442  0.6408  0.734189
# 27  Seed 3360   0.97753  0.826742   0.858557  0.6592  0.745786
# 28  Seed 3596   0.97744  0.822147   0.865672  0.6496  0.742230
# 29  Seed 1998   0.97703  0.820037   0.860112  0.6456  0.737576
#
#                                Top1 Feature Name  Top1 Feature Value  \
# 0   one-hot-encoder__Use Chip_Online Transaction       102012.580865
# 1            one-hot-encoder__Merchant City_Rome        96813.522418
# 2   one-hot-encoder__Use Chip_Online Transaction       110066.265115
# 3   one-hot-encoder__Use Chip_Online Transaction       108827.057910
# 4   one-hot-encoder__Use Chip_Online Transaction       111833.543153
# 5   one-hot-encoder__Use Chip_Online Transaction       110946.268254
# 6   one-hot-encoder__Use Chip_Online Transaction       111222.052997
# 7   one-hot-encoder__Use Chip_Online Transaction       108297.674110
# 8   one-hot-encoder__Use Chip_Online Transaction       101659.232464
# 9   one-hot-encoder__Use Chip_Online Transaction       105861.093602
# 10  one-hot-encoder__Use Chip_Online Transaction        98315.122344
# 11  one-hot-encoder__Use Chip_Online Transaction       109773.897113
# 12  one-hot-encoder__Use Chip_Online Transaction       105871.567385
# 13  one-hot-encoder__Use Chip_Online Transaction       111515.135981
# 14  one-hot-encoder__Use Chip_Online Transaction       112846.921011
# 15  one-hot-encoder__Use Chip_Online Transaction       114275.226609
# 16           one-hot-encoder__Merchant City_Rome        97940.043693
# 17  one-hot-encoder__Use Chip_Online Transaction       104948.948664
# 18           one-hot-encoder__Merchant City_Rome        96233.418195
# 19  one-hot-encoder__Use Chip_Online Transaction       109098.213647
# 20  one-hot-encoder__Use Chip_Online Transaction       108523.046560
# 21  one-hot-encoder__Use Chip_Online Transaction       108865.936647
# 22  one-hot-encoder__Use Chip_Online Transaction       107887.657091
# 23  one-hot-encoder__Use Chip_Online Transaction       110049.970356
# 24  one-hot-encoder__Use Chip_Online Transaction       112016.725095
# 25  one-hot-encoder__Use Chip_Online Transaction       111817.224558
# 26  one-hot-encoder__Use Chip_Online Transaction       102000.601975
# 27           one-hot-encoder__Merchant City_Rome        96794.510599
# 28           one-hot-encoder__Merchant City_Rome        97709.521722
# 29  one-hot-encoder__Use Chip_Online Transaction       105665.010714
#
#                                Top2 Feature Name  Top2 Feature Value  ...  \
# 0            one-hot-encoder__Merchant City_Rome        99019.352568  ...
# 1   one-hot-encoder__Use Chip_Online Transaction        78161.579472  ...
# 2            one-hot-encoder__Merchant City_Rome        96943.300092  ...
# 3            one-hot-encoder__Merchant City_Rome        98023.552222  ...
# 4            one-hot-encoder__Merchant City_Rome        98790.113807  ...
# 5            one-hot-encoder__Merchant City_Rome        98743.084996  ...
# 6            one-hot-encoder__Merchant City_Rome        97267.577724  ...
# 7            one-hot-encoder__Merchant City_Rome        98597.637020  ...
# 8            one-hot-encoder__Merchant City_Rome        97261.110310  ...
# 9            one-hot-encoder__Merchant City_Rome        96041.645807  ...
# 10           one-hot-encoder__Merchant City_Rome        95855.287660  ...
# 11           one-hot-encoder__Merchant City_Rome        96431.766157  ...
# 12           one-hot-encoder__Merchant City_Rome        97121.139130  ...
# 13           one-hot-encoder__Merchant City_Rome        99965.580413  ...
# 14           one-hot-encoder__Merchant City_Rome        98646.363454  ...
# 15           one-hot-encoder__Merchant City_Rome        98433.598657  ...
# 16                         standard_scaler__Year        93535.518739  ...
# 17           one-hot-encoder__Merchant City_Rome        99410.739068  ...
# 18                         standard_scaler__Year        78112.624875  ...
# 19           one-hot-encoder__Merchant City_Rome        98357.338620  ...
# 20           one-hot-encoder__Merchant City_Rome        93155.603308  ...
# 21           one-hot-encoder__Merchant City_Rome        99844.821837  ...
# 22           one-hot-encoder__Merchant City_Rome        94854.727049  ...
# 23           one-hot-encoder__Merchant City_Rome        97936.925434  ...
# 24           one-hot-encoder__Merchant City_Rome        98291.547873  ...
# 25           one-hot-encoder__Merchant City_Rome        97066.378457  ...
# 26           one-hot-encoder__Merchant City_Rome        98644.470185  ...
# 27                         standard_scaler__Year        77568.452913  ...
# 28                         standard_scaler__Year        75941.662898  ...
# 29           one-hot-encoder__Merchant City_Rome        98297.776350  ...
#
#                             Top16 Feature Name  Top16 Feature Value  \
# 0   one-hot-encoder__Merchant City_Mexico City          3576.025889
# 1      one-hot-encoder__Merchant City_Istanbul          4905.435569
# 2         one-hot-encoder__Time_of_Day_Morning          3230.903707
# 3   one-hot-encoder__Merchant City_Mexico City          3863.367327
# 4        standard_scaler__Person_Income_toDebt          4079.130177
# 5        one-hot-encoder__Merchant City_ONLINE          3237.264400
# 6        one-hot-encoder__Time_of_Day_Midnight          3081.581146
# 7   one-hot-encoder__Card Type_Debit (Prepaid)          4473.216265
# 8         one-hot-encoder__Time_of_Day_Evening          3587.359185
# 9   one-hot-encoder__Merchant City_Mexico City          4607.110013
# 10  one-hot-encoder__Card Type_Debit (Prepaid)          3992.511852
# 11     one-hot-encoder__Time_of_Day_Late Night          4368.680806
# 12     one-hot-encoder__Time_of_Day_Late Night          4120.573114
# 13          one-hot-encoder__Weekday_Wednesday          2890.172491
# 14        one-hot-encoder__Merchant City_Abuja          3625.922349
# 15        one-hot-encoder__Merchant City_Abuja          3555.620599
# 16  one-hot-encoder__Merchant City_Mexico City          4612.301586
# 17           one-hot-encoder__Time_of_Day_Noon          3559.872602
# 18  one-hot-encoder__Merchant City_Mexico City          4966.448638
# 19       one-hot-encoder__Merchant City_ONLINE          3279.357594
# 20           one-hot-encoder__Time_of_Day_Noon          4339.362989
# 21  one-hot-encoder__Merchant City_Mexico City          4190.972811
# 22       one-hot-encoder__Merchant City_ONLINE          4452.432945
# 23       one-hot-encoder__Merchant City_ONLINE          3389.377569
# 24  one-hot-encoder__Merchant City_Mexico City          4128.614257
# 25       one-hot-encoder__Merchant City_ONLINE          3367.125045
# 26        one-hot-encoder__Merchant City_Abuja          3101.032383
# 27       standard_scaler__Person_Income_toDebt          4131.916199
# 28                standard_scaler__Current Age          3775.126304
# 29     one-hot-encoder__Time_of_Day_Late Night          4410.621241
#
#                             Top17 Feature Name  Top17 Feature Value  \
# 0   one-hot-encoder__Card Type_Debit (Prepaid)          3304.502712
# 1   one-hot-encoder__Card Type_Debit (Prepaid)          3620.104294
# 2            one-hot-encoder__Time_of_Day_Noon          3150.190018
# 3        standard_scaler__Person_Income_toDebt          3825.622949
# 4        one-hot-encoder__Time_of_Day_Midnight          3086.191851
# 5        standard_scaler__Person_Income_toDebt          3209.741066
# 6         one-hot-encoder__Merchant City_Abuja          3068.949191
# 7    one-hot-encoder__Time_of_Day_Late Morning          3361.142496
# 8        standard_scaler__Person_Income_toDebt          3569.439497
# 9        standard_scaler__Person_Income_toDebt          3454.575098
# 10           one-hot-encoder__Time_of_Day_Noon          3699.749251
# 11        one-hot-encoder__Merchant City_Abuja          3491.194994
# 12           one-hot-encoder__Time_of_Day_Noon          4005.402945
# 13        one-hot-encoder__Merchant City_Abuja          2767.000992
# 14       one-hot-encoder__Merchant City_ONLINE          3018.622958
# 15       standard_scaler__Person_Income_toDebt          3512.302642
# 16       standard_scaler__Person_Income_toDebt          3389.644716
# 17       standard_scaler__Person_Income_toDebt          3110.711745
# 18                standard_scaler__Current Age          4655.282225
# 19           one-hot-encoder__Time_of_Day_Noon          3253.726090
# 20     one-hot-encoder__Time_of_Day_Late Night          4053.354194
# 21       standard_scaler__Person_Income_toDebt          3621.221485
# 22     one-hot-encoder__Time_of_Day_Late Night          3975.347395
# 23           one-hot-encoder__Time_of_Day_Noon          3341.039253
# 24           one-hot-encoder__Time_of_Day_Noon          3394.623659
# 25   one-hot-encoder__Time_of_Day_Late Morning          3225.895587
# 26       standard_scaler__Person_Income_toDebt          3072.551613
# 27           one-hot-encoder__Time_of_Day_Noon          4008.246266
# 28        one-hot-encoder__Merchant City_Abuja          3085.506057
# 29           one-hot-encoder__Time_of_Day_Noon          3980.868687
#
#                             Top18 Feature Name  Top18 Feature Value  \
# 0            one-hot-encoder__Weekday_Saturday          3187.011507
# 1        one-hot-encoder__Merchant City_ONLINE          3574.766668
# 2         one-hot-encoder__Merchant City_Abuja          3009.542641
# 3            one-hot-encoder__Time_of_Day_Noon          3147.199053
# 4         one-hot-encoder__Merchant City_Abuja          2846.305020
# 5         one-hot-encoder__Merchant City_Abuja          3121.175154
# 6        standard_scaler__Person_Income_toDebt          3066.015025
# 7         one-hot-encoder__Merchant City_Abuja          3125.922680
# 8         one-hot-encoder__Merchant City_Abuja          3340.362240
# 9         one-hot-encoder__Merchant City_Abuja          3380.538336
# 10       standard_scaler__Person_Income_toDebt          3453.155381
# 11   one-hot-encoder__Time_of_Day_Late Morning          3477.142046
# 12        one-hot-encoder__Merchant City_Abuja          3265.064702
# 13     standard_scaler__Location_Income_toDebt          2761.155272
# 14           one-hot-encoder__Time_of_Day_Noon          2885.980607
# 15       one-hot-encoder__Time_of_Day_Midnight          3308.807590
# 16           one-hot-encoder__Time_of_Day_Noon          3246.346496
# 17           one-hot-encoder__Weekday_Saturday          3019.990591
# 18  one-hot-encoder__Card Type_Debit (Prepaid)          4575.247135
# 19        one-hot-encoder__Merchant City_Abuja          3149.840594
# 20        one-hot-encoder__Merchant City_Abuja          3543.058002
# 21           one-hot-encoder__Time_of_Day_Noon          3383.438986
# 22        one-hot-encoder__Merchant City_Abuja          3587.239715
# 23       standard_scaler__Person_Income_toDebt          3269.062266
# 24        one-hot-encoder__Merchant City_Abuja          3331.865868
# 25        one-hot-encoder__Merchant City_Abuja          3194.309661
# 26           one-hot-encoder__Time_of_Day_Noon          3069.857897
# 27  one-hot-encoder__Merchant City_Mexico City          3968.576511
# 28   one-hot-encoder__Time_of_Day_Late Morning          3008.039536
# 29       standard_scaler__Person_Income_toDebt          3727.825408
#
#                            Top19 Feature Name  Top19 Feature Value  \
# 0        one-hot-encoder__Merchant City_Abuja          3118.106460
# 1        one-hot-encoder__Merchant City_Abuja          3164.290860
# 2           one-hot-encoder__Weekday_Saturday          2953.229422
# 3        one-hot-encoder__Merchant City_Abuja          2967.011548
# 4        one-hot-encoder__Time_of_Day_Morning          2717.054299
# 5   one-hot-encoder__Time_of_Day_Late Morning          2726.818186
# 6          one-hot-encoder__Weekday_Wednesday          2812.903088
# 7           one-hot-encoder__Time_of_Day_Noon          2719.201303
# 8       one-hot-encoder__Time_of_Day_Midnight          3027.512424
# 9           one-hot-encoder__Time_of_Day_Noon          3090.150784
# 10       one-hot-encoder__Merchant City_Abuja          3320.462707
# 11      standard_scaler__Person_Income_toDebt          3348.545779
# 12          one-hot-encoder__Weekday_Saturday          3030.401197
# 13          one-hot-encoder__Weekday_Saturday          2709.647898
# 14      one-hot-encoder__Time_of_Day_Midnight          2788.223516
# 15          one-hot-encoder__Time_of_Day_Noon          3106.290219
# 16       one-hot-encoder__Merchant City_Abuja          3231.396877
# 17       one-hot-encoder__Merchant City_Abuja          2931.825222
# 18          one-hot-encoder__Time_of_Day_Noon          3810.376861
# 19       one-hot-encoder__Time_of_Day_Morning          2916.244214
# 20      standard_scaler__Person_Income_toDebt          3299.025208
# 21       one-hot-encoder__Merchant City_Abuja          3308.852996
# 22       one-hot-encoder__Time_of_Day_Morning          3040.122540
# 23      one-hot-encoder__Time_of_Day_Midnight          3218.859652
# 24       one-hot-encoder__Time_of_Day_Morning          2834.002720
# 25         one-hot-encoder__Weekday_Wednesday          3164.211980
# 26         one-hot-encoder__Weekday_Wednesday          2941.248919
# 27       one-hot-encoder__Merchant City_Abuja          3161.277608
# 28      standard_scaler__Person_Income_toDebt          2982.507947
# 29       one-hot-encoder__Merchant City_Abuja          3358.535575
#
#                            Top20 Feature Name  Top20 Feature Value
# 0       standard_scaler__Person_Income_toDebt          2961.409719
# 1       standard_scaler__Person_Income_toDebt          2864.567007
# 2   one-hot-encoder__Time_of_Day_Late Morning          2855.555953
# 3   one-hot-encoder__Time_of_Day_Late Morning          2573.216455
# 4            one-hot-encoder__Weekday_Tuesday          2663.585608
# 5           one-hot-encoder__Weekday_Saturday          2720.346409
# 6     standard_scaler__Location_Income_toDebt          2539.858140
# 7          one-hot-encoder__Weekday_Wednesday          2676.928950
# 8          one-hot-encoder__Weekday_Wednesday          2800.798382
# 9           one-hot-encoder__Weekday_Saturday          2739.726718
# 10       one-hot-encoder__Time_of_Day_Morning          3137.869478
# 11       one-hot-encoder__Time_of_Day_Morning          3149.624861
# 12      standard_scaler__Person_Income_toDebt          3004.133527
# 13      one-hot-encoder__Time_of_Day_Midnight          2623.266833
# 14       one-hot-encoder__Time_of_Day_Morning          2716.027613
# 15          one-hot-encoder__Weekday_Saturday          3007.441816
# 16          one-hot-encoder__Weekday_Thursday          2945.921856
# 17    standard_scaler__Location_Income_toDebt          2462.520247
# 18       one-hot-encoder__Merchant City_Abuja          2921.333607
# 19         one-hot-encoder__Weekday_Wednesday          2908.048086
# 20  one-hot-encoder__Time_of_Day_Late Morning          2635.426857
# 21  one-hot-encoder__Time_of_Day_Late Morning          2490.658821
# 22  one-hot-encoder__Time_of_Day_Late Morning          2871.317494
# 23         one-hot-encoder__Weekday_Wednesday          2839.666608
# 24          one-hot-encoder__Weekday_Saturday          2411.538602
# 25          one-hot-encoder__Time_of_Day_Noon          2902.948586
# 26          one-hot-encoder__Weekday_Saturday          2711.162429
# 27       one-hot-encoder__Time_of_Day_Morning          2874.864532
# 28    standard_scaler__Location_Income_toDebt          2672.163781
# 29       one-hot-encoder__Time_of_Day_Morning          3200.786182
#
# [30 rows x 46 columns]
